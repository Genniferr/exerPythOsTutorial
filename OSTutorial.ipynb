# %%
import os

# %%
print(dir(os))
# Out:
# ['CLD_CONTINUED', 'CLD_DUMPED', 'CLD_EXITED', 'CLD_TRAPPED', 'DirEntry', 'EX_CANTCREAT', 'EX_CONFIG', 'EX_DATAERR', 'EX_IOERR', 'EX_NOHOST', 'EX_NOINPUT', 'EX_NOPERM', 'EX_NOUSER', 'EX_OK', 'EX_OSERR', 'EX_OSFILE', 'EX_PROTOCOL', 'EX_SOFTWARE', 'EX_TEMPFAIL', 'EX_UNAVAILABLE', 'EX_USAGE', 'F_LOCK', 'F_OK', 'F_TEST', 'F_TLOCK', 'F_ULOCK', 'MutableMapping', 'NGROUPS_MAX', 'O_ACCMODE', 'O_APPEND', 'O_ASYNC', 'O_CLOEXEC', 'O_CREAT', 'O_DIRECTORY', 'O_DSYNC', 'O_EXCL', 'O_EXLOCK', 'O_NDELAY', 'O_NOCTTY', 'O_NOFOLLOW', 'O_NONBLOCK', 'O_RDONLY', 'O_RDWR', 'O_SHLOCK', 'O_SYNC', 'O_TRUNC', 'O_WRONLY', 'POSIX_SPAWN_CLOSE', 'POSIX_SPAWN_DUP2', 'POSIX_SPAWN_OPEN', 'PRIO_PGRP', 'PRIO_PROCESS', 'PRIO_USER', 'P_ALL', 'P_NOWAIT', 'P_NOWAITO', 'P_PGID', 'P_PID', 'P_WAIT', 'PathLike', 'RTLD_GLOBAL', 'RTLD_LAZY', 'RTLD_LOCAL', 'RTLD_NODELETE', 'RTLD_NOLOAD', 'RTLD_NOW', 'R_OK', 'SCHED_FIFO', 'SCHED_OTHER', 'SCHED_RR', 'SEEK_CUR', 'SEEK_END', 'SEEK_SET', 'ST_NOSUID', 'ST_RDONLY', 'TMP_MAX', 'WCONTINUED'
# ...

# %%
print(os.getcwd())
# Out:
# /Users/genniferrubin/Desktop/NURS6806/myProject/exerPythOsTutorial

# %%
os.chdir('/Users/genniferrubin/Desktop/')

# %%
os.listdir()
# Out:
# ['hello.py',
#  'NI Courses.png',
#  'demo.txt',
#  '.DS_Store',
#  '.localized',
#  'IMG_0290.jpeg',
#  'NURS6806',
#  'GitHub',
#  'Folders']

# %%
os.mkdir('OS-Demo-2')

# %%
os.makedirs('OS-Demo-4/Sub-Dir-3')

# %%
os.rmdir('OS-Demo-2')

# %%
os.removedirs('OS-Demo-4/Sub-Dir-3')

# %%
os.rename('demo.txt','test.txt')

# %%
print(os.stat('test.txt'))
# Out:
# os.stat_result(st_mode=33188, st_ino=4329308671, st_dev=16777220, st_nlink=1, st_uid=501, st_gid=501, st_size=14, st_atime=1598986746, st_mtime=1598986200, st_ctime=1598986745)

# %%
print(os.stat('test.txt').st_mtime)
# Out:
# 1598986200.884032

# %%
mod_time = os.stat('test.txt').st_mtime

# %%
print(datetime.fromtimestamp(mod_time))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-75fb7b6e913d> in <module>
# ----> 1 print(datetime.fromtimestamp(mod_time))
#
# NameError: name 'datetime' is not defined

# %%
from datetime import datetime

# %%
print(datetime.fromtimestamp(mod_time))
# Out:
# 2020-09-01 12:50:00.884032

# %%
for dirpath, dirnames, filenames in os.walk('/Users/genniferrubin/Desktop/'):
    print('Current Path:', dirpath)
    print('Directories:', dirnames)
    print('Files:', filenames)
    print()
# Out:
# Current Path: /Users/genniferrubin/Desktop/
# Directories: ['NURS6806', 'GitHub', 'Folders']
# Files: ['hello.py', 'NI Courses.png', '.DS_Store', '.localized', 'IMG_0290.jpeg', 'test.txt']
#
# Current Path: /Users/genniferrubin/Desktop/NURS6806
# Directories: ['myProject']
# Files: ['.DS_Store']
#
# Current Path: /Users/genniferrubin/Desktop/NURS6806/myProject
# Directories: ['exerPythFilesTutorial', 'exerPythCheckInstal', 'exerPythOsTutorial', 'exerPythCondaEnvPkgs', 'exerGitPractice', '.git', 'exerPythModPackTutorial']
# Files: ['.DS_Store', 'myNombre.txt', 'myName.txt']
#
# Current Path: /Users/genniferrubin/Desktop/NURS6806/myProject/exerPythFilesTutorial
# Directories: ['.git']
# Files: ['README.md']
#
# Current Path: /Users/genniferrubin/Desktop/NURS6806/myProject/exerPythFilesTutorial/.git
# Directories: ['objects', 'info', 'logs', 'hooks', 'refs']
# Files: ['config', 'HEAD', 'description', 'index', 'packed-refs']
#
# ...

# %%
print(os.environ.get('HOME'))
# Out:
# /Users/genniferrubin

# %%
file_path = os.path.join(os.environ.get('HOME'),'test.txt')

# %%
print (os.path.basename('/tmp/test.txt'))
# Out:
# test.txt

# %%
print (os.path.dirname('/tmp/test.txt'))
# Out:
# /tmp

# %%
print (os.path.split('/tmp/test.txt'))
# Out:
# ('/tmp', 'test.txt')

# %%
print (os.path.exists('/tmp/test.txt'))
# Out:
# False

# %%
print (os.path.isdir('/tmp/test.txt'))
# Out:
# False

# %%
print (os.path.isfile('/tmp/test.txt'))
# Out:
# False

# %%
print (os.path.splitext('/tmp/test.txt'))
# Out:
# ('/tmp/test', '.txt')

# %%
https://docs.python.org/3/
# Out:
#   File "<ipython-input-27-887aafffa0ac>", line 1
#     https://docs.python.org/3/
#           ^
# SyntaxError: invalid syntax

# %%
https://docs.python.org/3/tutorial/stdlib.html#operating-system-interface
# Out:
#   File "<ipython-input-28-e427000caf18>", line 1
#     https://docs.python.org/3/tutorial/stdlib.html#operating-system-interface
#           ^
# SyntaxError: invalid syntax
